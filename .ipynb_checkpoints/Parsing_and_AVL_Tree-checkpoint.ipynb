# %% [markdown]
# ## AVL Tree

# %%
class Node:
    def __init__(self, word, count):
        self.count = count
        self.word  = word
        self.left  = None
        self.right = None

# %%
class AVL(object):
    
    def __init__(self):
        self.nodes = 0
        self.root  = None

#########################################################
               ### Private Functions ###
#########################################################

    def __rotateLeft(self, root):
        if (not root):
            return root
        child  = root.right
        gchild = root.right.left

        child.left = root
        root.right = gchild
        return child

    def __rotateRight(self, root):        
        if (not root):
            return root 
        child  = root.left
        gchild = root.left.right

        root.left   = gchild
        child.right = root
        return child

    def __rotateLeftRight(self, root):
        if (not root):
            return root
        child   = root.left
        gchild  = root.left.right
        ggchild = root.left.right.left

        # Leftward Rotation
        gchild.left = child
        child.right = ggchild
        root.left   = gchild

        # Rightward Rotation
        return self.__rotateRight(root)

    def __rotateRightLeft(self, root):
        if (not root):
                return root
        child   = root.right;
        gchild  = root.right.left;
        ggchild = root.right.left.right;

        # Rightward Rotation
        gchild.right = child;
        child.left   = ggchild;
        root.right   = gchild;

        # Leftward Rotation
        return self.__rotateLeft(root)
    
    def findHeight(self, root):
        height = 0;
        if (not root):
            return height
        
        # Recursive Case
        height = max(height, self.findHeight(root.left))
        height = max(height, self.findHeight(root.right))

        # Base Case
        return height + 1

#########################################################
                ### Public Functions ###
#########################################################
    
    def insert(self, root, word):
        # BST Search
        if (not root):
            self.nodes += 1
            return Node(word, 1)
        elif (root.word > word):
            root.left  = self.insert(root.left, word)
        elif (root.word < word):
            root.right = self.insert(root.right, word)
        else:
            root.count += 1
            return root
                    
        # Balance tree
        bf = self.findHeight(root.left) - self.findHeight(root.right)
        if (bf > 1):
#             child_bf = self.findHeight(root.left.left) - self.findHeight(root.left.right)
            if (word < node.left.word): 
#                 print("{0} Right".format(root.word))
                return self.__rotateRight(root)
            else:
#                 print("{0} LeftRight".format(root.word))
                return self.__rotateLeftRight(root)
        elif (bf < -1):
#             child_bf = self.findHeight(root.right.left) - self.findHeight(root.right.right)
            if (word < node.right.word):
#                 print("{0} RightLeft".format(root.word))
                return self.__rotateRightLeft(root)
            else:
#                 print("{0} Left".format(root.word))
                return self.__rotateLeft(root)

# key < node->left->key
                
        return root
    
    def add(self, word):
        if (not self.root):
            self.root = Node(word,1)
        else:
            self.root = self.insert(self.root, word)
            
    def printPreOrder(self, root):
        if (not root):
            return
        print("{0}: {1}".format(root.word, root.count))
        self.printPreOrder(root.left)
        self.printPreOrder(root.right)   
            
    def printInOrder(self, root):
        if (not root):
            return
        self.printInOrder(root.left)
        print("{0}: {1}".format(root.word, root.count))
        self.printInOrder(root.right)
        
    def printPostOrder(self, root):
        if (not root):
            return
        self.printPostOrder(root.left)
        self.printPostOrder(root.right)
        print("{0}: {1}".format(root.word, root.count))
        
    def printTree(self):
        self.printInOrder(self.root)
#         print()
#         self.printPreOrder(self.root)
#         print()
#         self.printPostOrder(self.root)
        
        
    def printCount(self):
        print(self.nodes)
        
    def printHeight(self):
        print(self.findHeight(self.root))

# %% [markdown]
# ## Parsing

# %%
from pathlib import Path as path
speeches = {"BattleCreekDec19_2019",
            "BemidjiSep18_2020", 
            "CharlestonFeb28_2020",
            "CharlotteMar2_2020",
            "CincinnatiAug1_2019",
            "ColoradorSpringsFeb20_2020",
            "DallasOct17_2019",
            "DesMoinesJan30_2020",
            "FayettevilleSep9_2019",
            "FayettevilleSep19_2020",
            "FreelandSep10_2020",
            "GreenvilleJul17_2019",
            "HendersonSep13_2020",
            "HersheyDec10_2019",
            "LasVegasFeb21_2020",
            "LatrobeSep3_2020",
            "LexingtonNov4_2019",
            "MilwaukeeJan14_2020",
            "MindenSep12_2020",
            "MinneapolisOct10_2019",
            "MosineeSep17_2020",
            "NewHampshireAug15_2019",
            "NewHampshireAug28_2020",
            "NewHampshireFeb10_2020",
            "NewMexicoSep16_2019",
            "OhioSep21_2020",
            "PhoenixFeb19_2020",
            "PittsburghSep22_2020",
            "TexasSep23_2019",
            "ToledoJan9_2020",
            "TulsaJun20_2020",
            "TupeloNov1_2019",
            "WildwoodJan28_2020",
            "Winston-SalemSep8_2020",
            "YumaAug18_2020"}

# %%
def input_command():
    "Takes in various user commands"
    
    speech = input('Enter Command: \n\
1. "FILE_NAME" to parse FILE_NAME.txt \n\
2. "PRINT"     to print available .txt files \n\
3. "ALL"       to parse all .txt files \n\
4. "QUIT"      to quit process \n')
    
    while (speech == 'PRINT'):
        print()
        for line in speeches:
            print(line)
        speech = input()
    return speech

# %%
# Initialize Structures
omap = AVL()

# Take in and format speech file
speech = input_command();
file_path = path(".\\Speeches\\" + speech + ".txt")

# Determine file format
if file_path.is_file():
    file = open(file_path,"r")
    
    word = ""
    for line in file: 
        line = line.lower()
        for char in line:
            if char == " " or char == "\"" or char == "," or char == "." or char == "?" or char == "…" \
                or char == "€" or char == "¦" or char >= "Ç":
                if word != "":
                    #print(word)
                    omap.add(word)
                word = ""
            else:
                word += char
        
    file.close()
    omap.printTree()
    
elif speech == 'ALL' or speech == '"ALL"':
    # Parse all inputs
    for speech in speeches:
        file_path = path(".\\Speeches\\" + speech + ".txt")
        print("Reached: %s" % speech)
        file = open(file_path,"r")

        word = ""
        for line in file: 
            line = line.lower()
            for char in line:
                if char == " " or char == "\"" or char == "," or char == "." or char == "?" or char == "…" \
                    or char == "€" or char == "¦" or char >= "Ç":
                    if word != "":
#                         print(word)
                        omap.add(word)
                    word = ""
                else:
                    word += char
        omap.printCount()
        omap.printHeight()
        file.close()
    omap.printTree()
    
elif speech == 'QUIT' or speech == '"QUIT"':
    print('Thank you, please come again!')
    
else:
    print('%s does not exist, please try again!' % file_path)
# Out:
# Enter Command:
# 1. "FILE_NAME" to parse FILE_NAME.txt
# 2. "PRINT"     to print available .txt files
# 3. "ALL"       to parse all .txt files
# 4. "QUIT"      to quit process
# ALL
# Reached: BattleCreekDec19_2019
# thank RightLeft
# thank Right
# pence Right
# president Right
# a Left
# you LeftRight
# to Right
# a RightLeft
# pence LeftRight
# president LeftRight
# victory RightLeft
# president Left
# michigan RightLeft
# great RightLeft
# and RightLeft
# job Right
# that Left
# you LeftRight
# thank Left
# but Right
# and Left
# christmas Right
# done Left
# michigan Left
# pence LeftRight
# pence RightLeft
# a RightLeft
# i'm LeftRight
# president RightLeft
# christmas Left
# to LeftRight
# thrilled Right
# together RightLeft
# journey Left
# remember Left
# job Left
# to RightLeft
# everybody RightLeft
# in RightLeft
# glory LeftRight
# the RightLeft
# merry Right
# done LeftRight
# be RightLeft
# is RightLeft
# pence RightLeft
# lady RightLeft
# i'm Left
# done LeftRight
# beautiful Left
# good LeftRight
# christmas LeftRight
# much RightLeft
# you LeftRight
# had Left
# together Left
# saying Left
# miracle RightLeft
# thank Right
# just RightLeft
# said LeftRight
# patriots Right
# thousands Left
# what RightLeft
# had Left
# he's Left
# than Right
# beautiful RightLeft
# very LeftRight
# never Left
# like RightLeft
# so LeftRight
# started Right
# christmas Left
# miracle LeftRight
# did Right
# fantastic LeftRight
# glory Right
# one RightLeft
# lucky Right
# i RightLeft
# really Right
# with Left
# america Right
# i LeftRight
# local Left
# they Left
# we've RightLeft
# celebrate LeftRight
# better Right
# job RightLeft
# job Right
# fixing RightLeft
# companies Right
# when RightLeft
# so Left
# be Right
# state RightLeft
# do LeftRight
# he's Right
# than Right
# like Right
# saying Left
# season RightLeft
# man LeftRight
# gasoline Left
# republican RightLeft
# when Left
# did Right
# still RightLeft
# expanding Right
# what LeftRight
# lucky Left
# great Right
# party Left
# better RightLeft
# raise LeftRight
# steal Left
# nobody's Right
# tax LeftRight
# nothing LeftRight
# taxes Right
# think LeftRight
# president Left
# best Left
# sacred LeftRight
# truly Left
# nafta RightLeft
# feel Right
# saying Left
# i'm Right
# happening RightLeft
# america LeftRight
# kind Left
# victory RightLeft
# all Left
# year Left
# unfortunately Left
# fantastic Left
# stopped Left
# feel RightLeft
# sitting LeftRight
# fun RightLeft
# build Right
# talking Right
# what's RightLeft
# sell RightLeft
# so LeftRight
# speech RightLeft
# sacred Left
# somebody Right
# and Left
# want Left
# 10 Left
# doing RightLeft
# potholes Right
# a Right
# miracle Left
# on Right
# your LeftRight
# proven RightLeft
# barriers Right
# they LeftRight
# whoever Left
# manufacturing RightLeft
# right Left
# see RightLeft
# word Right
# raise Right
# take Left
# the RightLeft
# vote RightLeft
# months LeftRight
# see Right
# companies RightLeft
# happened Left
# decided Right
# do LeftRight
# places Right
# worst Left
# gasoline Left
# bit Right
# than LeftRight
# this LeftRight
# pence RightLeft
# us LeftRight
# potholes LeftRight
# companies Left
# places RightLeft
# talked Right
# stuff LeftRight
# anyway Right
# hardworking Right
# people RightLeft
# understand LeftRight
# big RightLeft
# 10 RightLeft
# price LeftRight
# her LeftRight
# fixing RightLeft
# tremendous LeftRight
# is Right
# asked RightLeft
# how LeftRight
# can RightLeft
# very Right
# stops Left
# see Right
# talking RightLeft
# party LeftRight
# leave Left
# extent Left
# season Left
# michigan's RightLeft
# sits Right
# local Right
# done RightLeft
# fellows Left
# it's Left
# 40 Right
# please Right
# be Right
# for Right
# great LeftRight
# speech Right
# close Left
# word RightLeft
# somebody RightLeft
# that RightLeft
# fine Left
# sign Right
# months Left
# politically Left
# used LeftRight
# stuff RightLeft
# they LeftRight
# minute LeftRight
# democrats Left
# we're Right
# notice Left
# stop Left
# there Right
# if LeftRight
# figured LeftRight
# money Left
# standpoint RightLeft
# china Right
# places RightLeft
# decided Left
# about RightLeft
# being Left
# equipment Right
# ger LeftRight
# thriving RightLeft
# dairy Right
# subsidy RightLeft
# good LeftRight
# break LeftRight
# from Right
# deal's Left
# gasoline Right
# unions RightLeft
# sometimes Right
# especially Right
# back LeftRight
# early RightLeft
# son LeftRight
# negotiated Right
# other Right
# nobody's Right
# level LeftRight
# way LeftRight
# 40 Left
# 297% RightLeft
# 70 Left
# 297% Right
# lady Left
# administrations LeftRight
# for Left
# done Left
# raise Left
# well Right
# they Left
# building Left
# deal Right
# were LeftRight
# stop LeftRight
# man RightLeft
# many RightLeft
# could LeftRight
# ago RightLeft
# group RightLeft
# seriously Left
# 90 Left
# 80 RightLeft
# together RightLeft
# party LeftRight
# here's RightLeft
# 60 RightLeft
# is LeftRight
# 40 RightLeft
# republican Left
# from Right
# most RightLeft
# it LeftRight
# a Right
# 35 LeftRight
# invested Left
# it Left
# impeach LeftRight
# fine Right
# which RightLeft
# nuclear Left
# consider LeftRight
# company Left
# good Left
# due Left
# put Left
# don't RightLeft
# stuff RightLeft
# takes Left
# democrats LeftRight
# else LeftRight
# anything LeftRight
# won't LeftRight
# incredible RightLeft
# 90% RightLeft
# now Left
# didn't RightLeft
# son RightLeft
# could RightLeft
# sacred Right
# come LeftRight
# 401ks Left
# security LeftRight
# big LeftRight
# 90 Left
# kind LeftRight
# has RightLeft
# have LeftRight
# piece Left
# take LeftRight
# nafta Right
# equipment Right
# tariff Right
# beautiful Right
# finger Right
# 401k Left
# standpoint Right
# fantastic LeftRight
# star Right
# 266 LeftRight
# currency LeftRight
# playing Left
# patriots LeftRight
# have Left
# deal Right
# fixing Left
# need LeftRight
# armed LeftRight
# exactly Right
# anything Left
# made Left
# sitting RightLeft
# else RightLeft
# especially LeftRight
# mean RightLeft
# those RightLeft
# own RightLeft
# auto Left
# watcher Right
# again LeftRight
# who Left
# i LeftRight
# sell Right
# nothing RightLeft
# ammunition LeftRight
# economy's RightLeft
# willing RightLeft
# real LeftRight
# new Left
# numbers RightLeft
# me RightLeft
# baron LeftRight
# michigan LeftRight
# so Right
# space RightLeft
# no LeftRight
# happy RightLeft
# house Right
# ministers LeftRight
# up LeftRight
# publicity RightLeft
# oh LeftRight
# historically LeftRight
# tremendous RightLeft
# sign LeftRight
# price Left
# polls LeftRight
# would Left
# by RightLeft
# dictators Right
# life Left
# honored LeftRight
# military LeftRight
# tell RightLeft
# see RightLeft
# will Left
# consider Left
# casting Left
# decided LeftRight
# say LeftRight
# honored RightLeft
# like RightLeft
# whoever Left
# ford Left
# me LeftRight
# just RightLeft
# can LeftRight
# fill RightLeft
# 20% RightLeft
# 60 Right
# terrible Right
# buy LeftRight
# united RightLeft
# massive RightLeft
# person RightLeft
# last Left
# schools Right
# proven Right
# black Left
# easy RightLeft
# early LeftRight
# on LeftRight
# correct LeftRight
# didn't Left
# 20% Right
# 300 Right
# run LeftRight
# trip Left
# 35 LeftRight
# happened LeftRight
# sitting LeftRight
# together LeftRight
# merry Right
# understand LeftRight
# definitely LeftRight
# want LeftRight
# leave Right
# super LeftRight
# run RightLeft
# immigration LeftRight
# stand LeftRight
# 12 Left
# trade LeftRight
# 36 LeftRight
# flows Left
# never Left
# thank LeftRight
# from LeftRight
# mean RightLeft
# pay Left
# branch RightLeft
# many Left
# discussing Left
# last Left
# security Left
# watching Right
# all LeftRight
# cold LeftRight
# real Right
# thank RightLeft
# life Right
# all RightLeft
# happens Left
# local LeftRight
# companies LeftRight
# congress Right
# loan RightLeft
# up Left
# areas Left
# florida Right
# york Right
# if RightLeft
# shut Right
# dishonest Left
# stadiums Right
# cameras RightLeft
# build LeftRight
# come Left
# beautiful RightLeft
# figured Left
# playing Right
# said Right
# negotiated Left
# over Left
# percent Left
# cars Left
# talking Left
# word RightLeft
# state RightLeft
# into Right
# ger Right
# anyway RightLeft
# kind Left
# nuclear RightLeft
# 110 Right
# bit RightLeft
# loves Right
# anyway Right
# interest LeftRight
# policeman RightLeft
# potholes Right
# armed Left
# rich Right
# avoid Left
# liked RightLeft
# screen Left
# turn LeftRight
# ahead Left
# happen Right
# understand RightLeft
# are LeftRight
# let RightLeft
# patriotic Right
# out RightLeft
# season Right
# steal Right
# they've RightLeft
# total Left
# we LeftRight
# police Right
# election LeftRight
# put Left
# i'm RightLeft
# story RightLeft
# think Left
# incredible RightLeft
# heads Right
# incredible Right
# best LeftRight
# correct RightLeft
# president LeftRight
# 12 Right
# walk Left
# records RightLeft
# due RightLeft
# running RightLeft
# about RightLeft
# pronounce Left
# what's Right
# announced Right
# must've LeftRight
# period LeftRight
# cause RightLeft
# hollywood Right
# seen RightLeft
# party Left
# lied Right
# stage Right
# administrations RightLeft
# set Right
# poll LeftRight
# powerful Right
# clinton's Right
# victory Right
# leave LeftRight
# shortly Left
# hunts LeftRight
# labor Right
# you're LeftRight
# hear LeftRight
# mankind Right
# witch Right
# until RightLeft
# until Right
# obama RightLeft
# problem Left
# o'clock RightLeft
# wanted Left
# decided RightLeft
# day Right
# radical Right
# schools Right
# years Left
# disaster Left
# amount Right
# coming RightLeft
# fun LeftRight
# planes Left
# extraordinary Left
# little RightLeft
# when LeftRight
# obamacare RightLeft
# kids Right
# lucky LeftRight
# due LeftRight
# price RightLeft
# sitting RightLeft
# boot RightLeft
# colleges Right
# victory RightLeft
# two LeftRight
# slob RightLeft
# detroit LeftRight
# crooked LeftRight
# greats Left
# nights Left
# damn Left
# have Left
# sent Right
# ford Left
# products LeftRight
# been LeftRight
# did RightLeft
# making Left
# convention LeftRight
# put Right
# happened Right
# decades LeftRight
# i'm Right
# a RightLeft
# everybody RightLeft
# he's Left
# journey LeftRight
# ass RightLeft
# awfully Left
# could Right
# pick LeftRight
# sinister Right
# second Left
# based Left
# make LeftRight
# corrupt RightLeft
# two RightLeft
# put RightLeft
# excuse RightLeft
# stops Left
# trying RightLeft
# took RightLeft
# takes Right
# different RightLeft
# for LeftRight
# nafta Left
# give Left
# recession LeftRight
# branch LeftRight
# barack Right
# 2 Right
# fbi Left
# crazy Right
# appointed LeftRight
# 20 LeftRight
# 14 RightLeft
# impeached Left
# justice Left
# even LeftRight
# not Right
# stop RightLeft
# reason RightLeft
# journey RightLeft
# sudden RightLeft
# home LeftRight
# john RightLeft
# trump Left
# polls Left
# percent RightLeft
# which LeftRight
# biden Right
# 36 Left
# approval Left
# ronna LeftRight
# dairy Left
# how RightLeft
# grandfather Right
# democrats RightLeft
# country RightLeft
# change RightLeft
# fun Left
# stealth RightLeft
# deep RightLeft
# drugs Right
# central RightLeft
# potholes LeftRight
# universities RightLeft
# envy LeftRight
# government Left
# election Left
# home RightLeft
# nice RightLeft
# rid Right
# 2016 Left
# beating RightLeft
# blinking RightLeft
# coming LeftRight
# workers LeftRight
# actually Left
# loves Left
# funny RightLeft
# now Left
# after LeftRight
# politically Left
# level RightLeft
# historically LeftRight
# empty LeftRight
# 70 RightLeft
# woman Right
# him Left
# check LeftRight
# truly Left
# black Left
# until Right
# target LeftRight
# how Right
# 000 Right
# proof RightLeft
# pursuit Left
# bad Right
# tell Right
# son RightLeft
# slob LeftRight
# ago Right
# south Left
# instinct RightLeft
# lawless Right
# swamp Right
# china Left
# taxes Left
# cheapened LeftRight
# brand Right
# riots RightLeft
# open Left
# greatest Right
# court Left
# congressional RightLeft
# chair RightLeft
# womankind LeftRight
# than LeftRight
# folks LeftRight
# elite LeftRight
# saw LeftRight
# $45 LeftRight
# refer RightLeft
# media RightLeft
# house RightLeft
# quarter Left
# building Left
# round Left
# bring Left
# $45 Left
# d Right
# election Right
# receive Right
# early RightLeft
# terrible Left
# same LeftRight
# prohibitive Left
# guessing Left
# limbaugh RightLeft
# statements Left
# eight Left
# avoid Right
# including Left
# clue Right
# prime LeftRight
# business Right
# fisa Left
# he LeftRight
# gasoline LeftRight
# explode LeftRight
# showing Right
# disproven Right
# dishonesty RightLeft
# there's Right
# exciting Left
# stealth RightLeft
# pouring RightLeft
# disgusting RightLeft
# speeches RightLeft
# lying Left
# building Left
# conflict Right
# enemy Right
# new RightLeft
# called Right
# sinister RightLeft
# mention RightLeft
# happens LeftRight
# word Left
# haleigh! Right
# weeks Right
# hardworking Right
# suicide Right
# loser Left
# founding Right
# drug Right
# debates Right
# debbie Right
# without Right
# pence LeftRight
# totally Left
# process RightLeft
# proceeding RightLeft
# sir Right
# won Right
# president RightLeft
# pronouncing Left
# 401ks RightLeft
# partisan Left
# walks Left
# investors Right
# only RightLeft
# friend Right
# fictitious LeftRight
# ' LeftRight
# $45 Right
# it's RightLeft
# transcript Right
# democrat LeftRight
# reason Left
# nancy RightLeft
# getting Left
# senators RightLeft
# patriotic Right
# dying LeftRight
# nobody's Right
# clinton LeftRight
# budget Right
# assume LeftRight
# must've Right
# moving RightLeft
# time LeftRight
# ahead Right
# good Left
# eight-years Left
# muller RightLeft
# prime RightLeft
# ain't LeftRight
# $975 Right
# judge Left
# saw Right
# convention Left
# kind RightLeft
# knocked LeftRight
# here's Left
# drip Right
# allowed Right
# break RightLeft
# relaxing RightLeft
# victories Left
# japan LeftRight
# much Left
# care RightLeft
# fellows RightLeft
# crooked Right
# call LeftRight
# stuff LeftRight
# easy LeftRight
# kavanaugh Left
# country! Left
# refused Left
# asked RightLeft
# my Right
# famous Right
# sad Left
# professionally Left
# time Left
# edge RightLeft
# look RightLeft
# artificial Right
# damn RightLeft
# seriously Right
# love Right
# schools RightLeft
# crowds Left
# kitchen LeftRight
# people LeftRight
# actually LeftRight
# doesn't Right
# history RightLeft
# higher RightLeft
# it Right
# regulation LeftRight
# 72% Left
# casting LeftRight
# invoke RightLeft
# causes Left
# place Right
# murderer Right
# stupid Right
# violating Left
# supported Left
# lawless Right
# riots Left
# worse Right
# china Right
# history LeftRight
# some Right
# downturn RightLeft
# rush Left
# $1 Left
# individual Left
# ger LeftRight
# through Left
# polls RightLeft
# hundred RightLeft
# saved LeftRight
# hunts RightLeft
# fixing LeftRight
# forces Right
# coming RightLeft
# citizens Left
# justices Left
# park LeftRight
# accomplishing RightLeft
# vets Right
# world LeftRight
# post LeftRight
# emergency LeftRight
# jets LeftRight
# isn't Left
# god Left
# apologies RightLeft
# nancy LeftRight
# potholes Left
# swamp LeftRight
# finished Left
# jail Left
# coming LeftRight
# work LeftRight
# gone LeftRight
# tremendous LeftRight
# tens Left
# median RightLeft
# don't Right
# let's RightLeft
# ah Right
# lady Right
# human LeftRight
# such Left
# let Right
# sign Right
# ashamed RightLeft
# do Left
# pompous Left
# doctor Left
# lightly Right
# protesters LeftRight
# elected LeftRight
# last Left
# surrendering Left
# respirator RightLeft
# protesters RightLeft
# standing LeftRight
# phase Left
# adjustment Right
# scams Left
# means RightLeft
# choice Right
# capped Right
# empty Left
# agree Left
# pro Right
# liar! RightLeft
# beating Right
# absolute Right
# billions RightLeft
# ship Right
# allowing Left
# swamp RightLeft
# gain RightLeft
# running Right
# refer LeftRight
# your RightLeft
# give LeftRight
# please Right
# shoot RightLeft
# angry RightLeft
# display Left
# terrible Right
# escalator LeftRight
# odd LeftRight
# negotiated Right
# stories RightLeft
# shape Right
# sandusky Left
# looks Left
# announce Right
# foxconn Left
# garbage Right
# cleaning LeftRight
# waste Left
# salesman Left
# natural Right
# moved LeftRight
# trying LeftRight
# should RightLeft
# generals RightLeft
# boom LeftRight
# believed RightLeft
# invested LeftRight
# christmas! RightLeft
# kent LeftRight
# more Left
# must Left
# michigan's RightLeft
# forgot RightLeft
# east Right
# nation's Left
# rnc LeftRight
# what Right
# bit Right
# democracy LeftRight
# notice RightLeft
# tried LeftRight
# secret RightLeft
# stop LeftRight
# gorsuch Right
# protesters Right
# changed RightLeft
# pursuit Left
# nope Right
# car Left
# central Left
# guessing Right
# done RightLeft
# medical RightLeft
# ger RightLeft
# like RightLeft
# polluted Left
# chairwoman RightLeft
# paris LeftRight
# detroit RightLeft
# wires LeftRight
# giving Left
# labor Left
# heard RightLeft
# preexisting RightLeft
# subsidy Left
# pronounce LeftRight
# 2144
# 13
# Reached: FreelandSep10_2020
# friend LeftRight
# office RightLeft
# outside RightLeft
# ended Left
# war Left
# left Right
# change Right
# drain Right
# surprised RightLeft
# wisconsin Right
# respect Left
# bush LeftRight
# even LeftRight
# suppression LeftRight
# hope RightLeft
# land RightLeft
# playing LeftRight
# heads Left
# really Left
# plane Right
# result LeftRight
# usually RightLeft
# flights Left
# terry LeftRight
# house LeftRight
# small Left
# yes LeftRight
# mankind LeftRight
# poor RightLeft
# gasoline Left
# park Right
# votes Left
# citizens Left
# security LeftRight
# blow Right
# interest Left
# miss RightLeft
# personal RightLeft
# asked LeftRight
# obamacare RightLeft
# it Right
# country Right
# edge Left
# usmca RightLeft
# defending Right
# fellows Right
# pneumonia LeftRight
# putting RightLeft
# cleaning RightLeft
# party Right
# virtually Left
# phone LeftRight
# violent Left
# killing LeftRight
# down RightLeft
# canada RightLeft
# victory Left
# drip Right
# am Left
# honor LeftRight
# pelosi Right
# deals Left
# returning LeftRight
# important RightLeft
# hillary LeftRight
# largely Right
# taxpayer RightLeft
# down LeftRight
# powerful RightLeft
# dishwashers RightLeft
# liar! RightLeft
# communities Right
# leaves RightLeft
# terminally Left
# republicans Left
# subsidy RightLeft
# zeros Left
# pronouncing Right
# little Left
# were Left
# anymore LeftRight
# dershowitz Left
# sent Left
# wine Left
# michelle Right
# bringing RightLeft
# six Right
# law RightLeft
# markets RightLeft
# line RightLeft
# some Right
# may Right
# loan Right
# illegality RightLeft
# cox LeftRight
# characters Right
# mom Right
# heights RightLeft
# endless Left
# history Left
# read Right
# barack Right
# impeachment Left
# natural Right
# primary Left
# politically Left
# faced LeftRight
# chatfield Right
# convention LeftRight
# dollar Left
# terrific Left
# denouncing RightLeft
# home RightLeft
# total Left
# wants Left
# russia RightLeft
# best LeftRight
# walk LeftRight
# chair LeftRight
# borders RightLeft
# has Left
# haleigh Right
# journal Right
# couple Left
# pete! Left
# efforts Right
# talk LeftRight
# central RightLeft
# greatest Left
# is Left
# declaring Right
# complained Left
# patrol RightLeft
# june RightLeft
# lowest Left
# era Left
# eternal Right
# too Right
# tariff Left
# rich LeftRight
# dare Right
# infrastructure Right
# 41 Left
# need LeftRight
# wires LeftRight
# picked Left
# expensive RightLeft
# mcdaniel Left
# true LeftRight
# from Left
# obama RightLeft
# believed Right
# television LeftRight
# friends LeftRight
# thank LeftRight
# local Right
# hearing RightLeft
# best Left
# prosecutor LeftRight
# hid RightLeft
# sounds LeftRight
# criminal RightLeft
# disproven RightLeft
# orange RightLeft
# admitted RightLeft
# economy Right
# 24 Right
# surrendering Right
# gave LeftRight
# reversing Right
# breaking Left
# automobiles RightLeft
# choice LeftRight
# continue Left
# military Right
# $100 Left
# 18 Left
# save LeftRight
# voters RightLeft
# tpp LeftRight
# acted- Right
# energy Left
# getting Left
# avoid RightLeft
# embarrassment Right
# sixth RightLeft
# improve LeftRight
# usa LeftRight
# baby Right
# ran LeftRight
# return Right
# $10 Left
# $3 Right
# 133 LeftRight
# him Right
# against RightLeft
# soon LeftRight
# look Right
# land LeftRight
# insane Right
# rose RightLeft
# defense Right
# fair LeftRight
# damn Right
# 10 Right
# catch LeftRight
# opens RightLeft
# those LeftRight
# belong Left
# back RightLeft
# submarine LeftRight
# depraved LeftRight
# also Right
# 32 Right
# avoid LeftRight
# $183 RightLeft
# ron LeftRight
# year Right
# quid Right
# ingram LeftRight
# colleges Right
# television Right
# anything Left
# truly Right
# later Right
# socialist RightLeft
# passe RightLeft
# more Right
# v RightLeft
# accused LeftRight
# tree Right
# jail Right
# achieve Left
# receive Left
# nothing Right
# elections Right
# killing RightLeft
# wear Left
# trying Left
# generally Right
# son's Left
# paying Left
# type Left
# nobody LeftRight
# nest Left
# friends Left
# relaxing Right
# undercount Right
# meetings Right
# agreement LeftRight
# team LeftRight
# ideally Left
# armed RightLeft
# nba LeftRight
# convicted RightLeft
# open Left
# sane Right
# forward Left
# republic LeftRight
# worry Right
# truck Right
# so RightLeft
# days RightLeft
# voters Right
# seven LeftRight
# billions Left
# know Left
# overwhelmingly Right
# unbelievable Right
# devotion LeftRight
# prime RightLeft
# ballots Left
# husband Left
# yesterday Right
# didn't Left
# antifa LeftRight
# correct LeftRight
# fairness Right
# versus LeftRight
# depleted LeftRight
# crummy Left
# lift Right
# the RightLeft
# rather LeftRight
# else Left
# 2018 Left
# deliberately Right
# fbi Left
# broken Right
# adjustment RightLeft
# ig RightLeft
# what LeftRight
# xi Right
# screaming LeftRight
# crashed Left
# leaders Right
# hoax LeftRight
# discussing LeftRight
# historically Right
# released Left
# 13 LeftRight
# reg RightLeft
# safe RightLeft
# machinery Left
# run LeftRight
# bans Right
# denouncing Right
# rock Right
# directly Left
# powerful Left
# painful Left
# socialism Right
# income RightLeft
# surprised Right
# appointed LeftRight
# comes Right
# crime Right
# upset LeftRight
# totally RightLeft
# three Right
# states Left
# mafia Left
# sure RightLeft
# 2 LeftRight
# understand RightLeft
# respirator Left
# cause Right
# turned Left
# pocahontas Right
# for Right
# needed RightLeft
# kavanaugh Right
# rich LeftRight
# unsupported Right
# destroyed Left
# 2840
# 14
# Reached: FayettevilleSep19_2020
# fbi LeftRight
# movie LeftRight
# good Right
# last LeftRight
# said LeftRight
# fight Right
# court Right
# inspector RightLeft
# getting Left
# screams Right
# repeat Right
# israeli Left
# early Right
# decades RightLeft
# thought RightLeft
# practiced RightLeft
# artificial LeftRight
# she Right
# nonsense Right
# thousands Right
# this Left
# haven't Right
# midwest LeftRight
# show Right
# stupid RightLeft
# governor RightLeft
# group RightLeft
# select RightLeft
# moolenaar Left
# pronounce Right
# now Right
# 51 RightLeft
# considered RightLeft
# dealt Left
# makes Right
# hadn't Left
# thugs Left
# cars Right
# households LeftRight
# number LeftRight
# legislators LeftRight
# proven Left
# 19 RightLeft
# irs LeftRight
# other Right
# ran RightLeft
# strong LeftRight
# pelosi's RightLeft
# countries LeftRight
# couldn't RightLeft
# conflict LeftRight
# survival Left
# systems RightLeft
# rise Left
# afford Right
# giving RightLeft
# they've Left
# choices RightLeft
# second LeftRight
# accord RightLeft
# internet RightLeft
# tim Right
# sir Left
# saving Right
# alan Right
# choice Left
# number RightLeft
# elite RightLeft
# wars Right
# spoiled LeftRight
# workers Left
# families Right
# duty Right
# smiling Right
# greats RightLeft
# used RightLeft
# bottom Right
# angry Right
# cookie RightLeft
# arrested RightLeft
# planes Left
# ending Left
# nominees Right
# me Left
# 975 Left
# contempt Left
# write RightLeft
# secretary Right
# 3rd LeftRight
# little Right
# offshoring RightLeft
# find Left
# meant Left
# lots Left
# does Right
# read RightLeft
# incensed RightLeft
# turley Right
# laura LeftRight
# career Left
# fantastic Right
# president LeftRight
# cures Right
# bergman Right
# believed RightLeft
# $100 RightLeft
# light LeftRight
# reelection LeftRight
# democracy Right
# automobiles LeftRight
# resume Left
# providing Left
# win Left
# wrong LeftRight
# wouldn't Left
# complained Right
# seven Left
# brings RightLeft
# building RightLeft
# natural Left
# indoctrinate RightLeft
# grand LeftRight
# theories RightLeft
# crazed Left
# rampant Left
# than Right
# independence Left
# needed Right
# movie Left
# complete RightLeft
# founders Right
# achieving LeftRight
# said Left
# really LeftRight
# officers RightLeft
# beloved RightLeft
# private RightLeft
# peters RightLeft
# wine LeftRight
# broadcasters Left
# quarter Left
# fellows Left
# fellas Left
# lousy LeftRight
# september Left
# flood Left
# forget Left
# follow RightLeft
# subject RightLeft
# science Left
# refer Right
# like LeftRight
# sewers RightLeft
# extremists RightLeft
# foxconn LeftRight
# numbers Left
# 82% RightLeft
# transformed RightLeft
# unconstitutional Right
# longterm Right
# boo! LeftRight
# decision RightLeft
# opens RightLeft
# recruit Left
# treat RightLeft
# move LeftRight
# accused LeftRight
# sued RightLeft
# democrats LeftRight
# abusive Left
# leading Right
# japanese RightLeft
# candidate Left
# china's RightLeft
# evenings RightLeft
# members Left
# 11 LeftRight
# sometimes RightLeft
# choices RightLeft
# migrants Left
# coach RightLeft
# invoke Left
# drops Right
# piece Left
# recognition Right
# sick Right
# show Left
# send Left
# fatality Right
# child LeftRight
# mandate Right
# name Right
# habit Right
# i've Left
# stuck Left
# versus Right
# pain RightLeft
# table LeftRight
# focus Right
# hikes LeftRight
# such Right
# shoot LeftRight
# hold Left
# while Right
# previous RightLeft
# chicago Right
# signs RightLeft
# met LeftRight
# late Left
# journal Right
# launched LeftRight
# color RightLeft
# let Right
# 182 Right
# team LeftRight
# except RightLeft
# teach Left
# upset Left
# supporting LeftRight
# ballot LeftRight
# assaults LeftRight
# either Right
# ginsburg Left
# done LeftRight
# get LeftRight
# throwing RightLeft
# stabbing Right
# fit LeftRight
# motor LeftRight
# water RightLeft
# europe Left
# fisa RightLeft
# sleep Right
# employee Left
# throwing Right
# shinzo Right
# day RightLeft
# i'm Left
# blackstone RightLeft
# guarantee Left
# scheme LeftRight
# witch Right
# kitchen Left
# aliens Right
# vehicle RightLeft
# bernie LeftRight
# hundred Right
# grilling Right
# liar Left
# geniuses RightLeft
# capital LeftRight
# town Right
# poisonous LeftRight
# through Left
# americans Left
# reversed Right
# sentence Left
# tpp Right
# adjustment LeftRight
# remove Right
# sad LeftRight
# 40 LeftRight
# policeman RightLeft
# killer Right
# loves RightLeft
# sean Right
# reports Right
# false Right
# $45 Right
# 16 LeftRight
# point Left
# learn LeftRight
# leading RightLeft
# moolenaar LeftRight
# sounds RightLeft
# they're RightLeft
# lightly Left
# boo! Left
# allow LeftRight
# endorsement Left
# kernel RightLeft
# negotiated RightLeft
# accomplishing LeftRight
# let's Right
# approving Left
# desantis RightLeft
# 42 RightLeft
# disgusting Right
# 600 RightLeft
# scream LeftRight
# award Right
# border Left
# manage Left
# drugs Left
# matter Right
# nato RightLeft
# fill RightLeft
# three RightLeft
# 72% Left
# nations Left
# airport Left
# nobody's Left
# capital RightLeft
# bulb Right
# day LeftRight
# amazing RightLeft
# lead LeftRight
# republican Right
# fact LeftRight
# electric RightLeft
# forward Right
# remove Left
# $5 RightLeft
# alfred Right
# carolyn RightLeft
# catastrophic Right
# hysterical Right
# hello RightLeft
# focused LeftRight
# 32% Right
# 75% LeftRight
# winner LeftRight
# mob Left
# democrats' RightLeft
# dignity LeftRight
# lost Right
# generation Left
# class Left
# expanding LeftRight
# written LeftRight
# painful RightLeft
# is Right
# spoken RightLeft
# changing Left
# flows Left
# too RightLeft
# means Right
# hours LeftRight
# 700% Right
# city Left
# patriotic LeftRight
# communities LeftRight
# charges Left
# wages Right
# ex-congressman LeftRight
# rallies LeftRight
# greats RightLeft
# legal LeftRight
# 3521
# 14
# Reached: HendersonSep13_2020
# her Right
# hardly Right
# pro Left
# pro-jobs RightLeft
# depressed RightLeft
# blatant Right
# records Left
# innocent LeftRight
# legals Right
# mom LeftRight
# largest Left
# 28 Left
# parent LeftRight
# damn Left
# champagne RightLeft
# interviewed Left
# clown Right
# sees RightLeft
# farm LeftRight
# pay RightLeft
# top RightLeft
# tortured LeftRight
# markets Left
# attorney Right
# great LeftRight
# familiar LeftRight
# shape RightLeft
# answered RightLeft
# further RightLeft
# serbia Left
# rotunda Left
# vicious Left
# was Right
# appease RightLeft
# cooper RightLeft
# pre-existing Left
# boring Left
# focused RightLeft
# you've RightLeft
# stacked LeftRight
# support Right
# 50 Left
# soldiers Right
# downstairs LeftRight
# trump/pence Right
# sits LeftRight
# extraordinary Right
# short LeftRight
# disaster Right
# build Left
# guys Left
# previous Right
# states Left
# aggressive Right
# pushing Right
# desperate Left
# fast Left
# door LeftRight
# desk RightLeft
# dershowitz Right
# despite Left
# sort Left
# expanding Left
# clinton Left
# handsome Right
# leader RightLeft
# development LeftRight
# networks Left
# eroding Right
# complained Right
# drip Right
# afford LeftRight
# badly Left
# rockets RightLeft
# jets Left
# mark Right
# cut LeftRight
# economy's Right
# phone Left
# forgotten RightLeft
# learned Right
# spiteful LeftRight
# mikey RightLeft
# owned RightLeft
# rid LeftRight
# branch LeftRight
# richard RightLeft
# he's Left
# has LeftRight
# quiet RightLeft
# spouse Right
# cupboards LeftRight
# uae RightLeft
# chuck RightLeft
# must LeftRight
# compactor LeftRight
# weapons RightLeft
# discussing Right
# cry LeftRight
# pouring Right
# justices RightLeft
# a+ RightLeft
# famous Left
# preexisting LeftRight
# advised Left
# devoted LeftRight
# why RightLeft
# closed RightLeft
# convince RightLeft
# firing Right
# restrictions Right
# branded Left
# orange Left
# refused Right
# abortion Right
# crummy RightLeft
# anti-police Right
# anti-vaccine LeftRight
# oath Right
# healthcare Right
# group Right
# withdrew LeftRight
# neighbors LeftRight
# space Right
# historic LeftRight
# premiums Right
# popular RightLeft
# strzok Right
# caucus LeftRight
# taxes RightLeft
# contractor Right
# attacking Right
# ahead Right
# motor Left
# rounding Left
# offshoring LeftRight
# arenas Left
# currency LeftRight
# added RightLeft
# complete RightLeft
# largely LeftRight
# accountable Right
# depleted Left
# not Right
# informed Right
# their Right
# lifetime Right
# split Right
# everything Left
# father Right
# retiring LeftRight
# vests RightLeft
# extreme Left
# plunge Right
# concerned RightLeft
# d Right
# sheet Left
# growth Right
# groups Left
# reminder RightLeft
# mills Left
# pours LeftRight
# founder LeftRight
# place LeftRight
# prosecutors RightLeft
# minister Right
# coworkers LeftRight
# ingram RightLeft
# trading Left
# sponsored Left
# designed Right
# police Right
# betrayals Left
# 3879
# 14
# Reached: CharlestonFeb28_2020
# charging RightLeft
# top-10 Left
# attacks RightLeft
# confidential LeftRight
# surge Left
# complete RightLeft
# explosion RightLeft
# leg Right
# poll Right
# corner RightLeft
# moving RightLeft
# stay LeftRight
# avalanche Left
# never Right
# power Left
# hurt Left
# ever LeftRight
# failed LeftRight
# maine LeftRight
# originally LeftRight
# professionally RightLeft
# premiums Left
# spouse Left
# loud RightLeft
# computers LeftRight
# blazing RightLeft
# truthful LeftRight
# federal RightLeft
# tariffs RightLeft
# resident Right
# respect LeftRight
# democracy Right
# 13 Left
# first Right
# ineffective Left
# threatens RightLeft
# thousands RightLeft
# went LeftRight
# comey Right
# lips Right
# ours Left
# 000 RightLeft
# views RightLeft
# enact RightLeft
# 20th Left
# joe RightLeft
# foxconn Left
# statement Right
# meanest Left
# factories Right
# witch Right
# stick LeftRight
# proof Left
# attorney LeftRight
# sledgehammer Right
# polls RightLeft
# repeatedly Left
# aoc Right
# enjoyed LeftRight
# wealth LeftRight
# large Right
# sand Left
# warren RightLeft
# his LeftRight
# choked RightLeft
# choke Left
# miles LeftRight
# journey LeftRight
# appoint Right
# 128 RightLeft
# crime LeftRight
# grand Right
# time LeftRight
# just LeftRight
# confiscate LeftRight
# brilliant LeftRight
# supplies LeftRight
# expired Left
# me LeftRight
# represented LeftRight
# earth Right
# rapids LeftRight
# normalize Left
# dream RightLeft
# march RightLeft
# loaded LeftRight
# stand LeftRight
# records LeftRight
# childhood LeftRight
# pocahontas RightLeft
# c Left
# decision LeftRight
# globalist LeftRight
# ensure LeftRight
# recognize Right
# fund Left
# illegality RightLeft
# 90% Left
# rapidly Right
# brutal RightLeft
# muller Left
# bergman RightLeft
# dossier Left
# retail LeftRight
# michelle Right
# registered LeftRight
# care RightLeft
# obliterated Left
# knife RightLeft
# okay Right
# produce Left
# summer Right
# 24 LeftRight
# opera Left
# appeal Left
# invoke Right
# spy LeftRight
# perished RightLeft
# caught Right
# trend Left
# nation Right
# envy Right
# cheats Right
# off Left
# providing Right
# screwed Left
# tech RightLeft
# levels Left
# opponent LeftRight
# overwhelming Right
# declaring RightLeft
# then RightLeft
# devotion RightLeft
# ads RightLeft
# nancy Left
# reputations Left
# unless Left
# excess Left
# tents Right
# stuff LeftRight
# john's RightLeft
# primetime RightLeft
# 2020 RightLeft
# nearest LeftRight
# reversed LeftRight
# she LeftRight
# jong-un Right
# basements Right
# instead Left
# stroke LeftRight
# movie RightLeft
# forever Right
# office Right
# blatant Left
# schumer RightLeft
# job Right
# beautiful Right
# blasio RightLeft
# continue LeftRight
# wild RightLeft
# dumbest Right
# lead LeftRight
# rains LeftRight
# hampshire Right
# 4239
# 15
# Reached: MosineeSep17_2020
# part Right
# week Left
# disastrous Right
# minneapolis Left
# contempt Left
# stupid Right
# susan Left
# accepted LeftRight
# religious Left
# standpoint RightLeft
# salaries Left
# tortured LeftRight
# solve LeftRight
# conflict RightLeft
# playing LeftRight
# prize Left
# sincere Left
# anti- Right
# 28 LeftRight
# satisfactory Left
# 29 LeftRight
# 266 Left
# strangling RightLeft
# cameras Right
# special RightLeft
# miles Left
# million LeftRight
# matters Right
# poorly Left
# steal LeftRight
# glad RightLeft
# compared RightLeft
# abe Left
# pulling Left
# catch RightLeft
# characters Right
# labor LeftRight
# anarchists Left
# anarchist Left
# insulting Right
# wealth Left
# revealed Left
# opposes RightLeft
# garbage Right
# politicians Left
# believe RightLeft
# word Right
# grilling Left
# key RightLeft
# hates Right
# whooped Right
# convention Right
